# %% [markdown]
# # Exploring protocol buffers for OHDSI Common Data Model

# %%
import glob,gzip
from collections import defaultdict
def load_data():
    data = defaultdict(dict)
    for fname in glob.glob('ohdsi_synthetic_data/*.gz'):
        with gzip.open(fname) as fh:
            fname = fname.split('/')[-1].split('.')[0]
            data[fname]['keys'] = fh.readline().strip()
            data[fname]['entries'] = [line.strip().split(',') for line in fh]
    return data
data = load_data()       
for fname in data:
    print fname,len(data[fname]['entries']),data[fname]['keys']
    break
# Out:
# CDM_LOCATION 626 LOCATION_ID,ADDRESS_1,ADDRESS_2,CITY,STATE,ZIP,COUNTY,LOCATION_SOURCE_VALUE

# %%
# !ls -lhS ohdsi_synthetic_data/*.gz
# Out:
# -rwxr-xr-x@ 1 aub3  staff   2.5M May 14  2016 ohdsi_synthetic_data/CDM_CONDITION_OCCURRENCE.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   1.1M May 14  2016 ohdsi_synthetic_data/CDM_DRUG_EXPOSURE.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   1.0M May 14  2016 ohdsi_synthetic_data/CDM_VISIT_OCCURRENCE.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   997K May 14  2016 ohdsi_synthetic_data/CDM_CONDITION_ERA.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   989K May 14  2016 ohdsi_synthetic_data/CDM_PROCEDURE_OCCURRENCE.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   510K May 14  2016 ohdsi_synthetic_data/CDM_DRUG_ERA.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   415K May 14  2016 ohdsi_synthetic_data/CDM_PROVIDER.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   205K May 14  2016 ohdsi_synthetic_data/CDM_OBSERVATION.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   173K May 14  2016 ohdsi_synthetic_data/CDM_CARE_SITE.csv.gz
# -rwxr-xr-x@ 1 aub3  staff    43K May 14  2016 ohdsi_synthetic_data/CDM_MEASUREMENT.csv.gz
# -rwxr-xr-x@ 1 aub3  staff    22K May 14  2016 ohdsi_synthetic_data/CDM_DEVICE_EXPOSURE.csv.gz
# -rwxr-xr-x@ 1 aub3  staff    21K May 12  2016 ohdsi_synthetic_data/CDM_PERSON.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   7.0K Jul  6  2015 ohdsi_synthetic_data/CDM_LOCATION.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   5.9K May 16  2016 ohdsi_synthetic_data/CDM_OBSERVATION_PERIOD.csv.gz
# -rwxr-xr-x@ 1 aub3  staff   354B May 14  2016 ohdsi_synthetic_data/CDM_DEATH.csv.gz

# %% [markdown]
# ## Computational Healthcare messages & enums

# %% [markdown]
# <img src="enums.png">
# <img src="messages.png">

# %% [markdown]
# ## Compiling protobuf definition into python

# %%
# !protoc --python_out=. ohdsi.proto

# %% [markdown]
# ### Using compiled protocols

# %%
import ohdsi_pb2 as ohdsi
Person = ohdsi.Person()
visit = Person.visits.add()
